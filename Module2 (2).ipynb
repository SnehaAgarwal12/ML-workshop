# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/dataset1.data')

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
  headers_data=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
print("headers\n",type(headers_data))
# Out:
# headers
#  <class 'list'>

# %%
df=pd.read_csv('/content/dataset1.data',names=headers_data)

# %%
df.tail()
# Out:
#    symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# -1          rwd           front       109.1   188.8  ...          141
# -1          rwd           front       109.1   188.8  ...          141
# -1          rwd           front       109.1   188.8  ...          173
# -1          rwd           front       109.1   188.8  ...          145
# -1          rwd           front       109.1   188.8  ...          141
#
#     fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
df.head()
# Out:
#   symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 3         ?       alfa-romero  gas       std        two  convertible
# 3         ?       alfa-romero  gas       std        two  convertible
# 1         ?       alfa-romero  gas       std        two    hatchback
# 2       164              audi  gas       std       four        sedan
# 2       164              audi  gas       std       four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 3          rwd           front        88.6   168.8  ...          130
# 3          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        94.5   171.2  ...          152
# 2          fwd           front        99.8   176.6  ...          109
# 2          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
df.tail(20)
# Out:
#    symboling normalized-losses    make fuel-type aspiration num-of-doors  \
#  2        94        volkswagen     gas       std       four        sedan
#  2        94        volkswagen     gas       std       four        sedan
#  2        94        volkswagen  diesel     turbo       four        sedan
#  2        94        volkswagen     gas       std       four        sedan
#  3         ?        volkswagen     gas       std        two  convertible
#  3       256        volkswagen     gas       std        two    hatchback
#  0         ?        volkswagen     gas       std       four        sedan
#  0         ?        volkswagen  diesel     turbo       four        sedan
#  0         ?        volkswagen     gas       std       four        wagon
# -2       103             volvo     gas       std       four        sedan
# -1        74             volvo     gas       std       four        wagon
# -2       103             volvo     gas       std       four        sedan
# ...

# %%
print(df.dtypes)
# Out:
# symboling             object
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#        wheel-base      length       width      height  curb-weight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000         205.000000  205.000000   205.000000
# mean    126.907317          10.142537   25.219512    30.751220
# std      41.642693           3.972040    6.542142     6.886443
# min      61.000000           7.000000   13.000000    16.000000
# ...

# %%
df.describe(include='all')
# Out:
#        symboling normalized-losses make fuel-type aspiration num-of-doors  \
# count        205               205  205       205        205          205
# unique        52                22    2         2          3            5
# top            ?            toyota  gas       std       four        sedan
# freq          41                32  185       168        114           96
# mean         NaN               NaN  NaN       NaN        NaN          NaN
# std          NaN               NaN  NaN       NaN        NaN          NaN
# min          NaN               NaN  NaN       NaN        NaN          NaN
# 25%          NaN               NaN  NaN       NaN        NaN          NaN
# 50%          NaN               NaN  NaN       NaN        NaN          NaN
# 75%          NaN               NaN  NaN       NaN        NaN          NaN
# max          NaN               NaN  NaN       NaN        NaN          NaN
#
#        drive-wheels engine-location  wheel-base      length  ...  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 3 to -1
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    object
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
# ...

# %%
df.to_csv("dataset2.csv")

# %%
df2=pd.read_csv('/content/dataset_2.data')

# %%
df2.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#    symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
# -1        95             volvo     gas       std       four        sedan
# -1        95             volvo  diesel     turbo       four        sedan
# -1        95             volvo     gas     turbo       four        sedan
#
#    drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# -1          rwd           front       109.1   188.8  ...          141
# -1          rwd           front       109.1   188.8  ...          141
# -1          rwd           front       109.1   188.8  ...          173
# -1          rwd           front       109.1   188.8  ...          145
# -1          rwd           front       109.1   188.8  ...          141
#
#     fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
df.replace("?",np.nan,inplace=True)
df.head(5)
# Out:
#   symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 3       NaN       alfa-romero  gas       std        two  convertible
# 3       NaN       alfa-romero  gas       std        two  convertible
# 1       NaN       alfa-romero  gas       std        two    hatchback
# 2       164              audi  gas       std       four        sedan
# 2       164              audi  gas       std       four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 3          rwd           front        88.6   168.8  ...          130
# 3          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        94.5   171.2  ...          152
# 2          fwd           front        99.8   176.6  ...          109
# 2          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# ...

# %%
df.head(10)
# Out:
#   symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 3       NaN       alfa-romero  gas       std        two  convertible
# 3       NaN       alfa-romero  gas       std        two  convertible
# 1       NaN       alfa-romero  gas       std        two    hatchback
# 2       164              audi  gas       std       four        sedan
# 2       164              audi  gas       std       four        sedan
# 2       NaN              audi  gas       std        two        sedan
# 1       158              audi  gas       std       four        sedan
# 1       NaN              audi  gas       std       four        wagon
# 1       158              audi  gas     turbo       four        sedan
# 0       NaN              audi  gas     turbo        two    hatchback
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 3          rwd           front        88.6   168.8  ...          130
# ...

# %%
missing_data=df.isnull()

# %%
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 3       True              False  False      False       False         False
# 3       True              False  False      False       False         False
# 1       True              False  False      False       False         False
# 2      False              False  False      False       False         False
# 2      False              False  False      False       False         False
#
#    drive-wheels  engine-location  wheel-base  length  ...  engine-size  \
# 3         False            False       False   False  ...        False
# 3         False            False       False   False  ...        False
# 1         False            False       False   False  ...        False
# 2         False            False       False   False  ...        False
# 2         False            False       False   False  ...        False
#
#    fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# ...

# %%
missing_data=df.notnull()
# Out:
#    symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 3      False               True  True       True        True          True
# 3      False               True  True       True        True          True
# 1      False               True  True       True        True          True
# 2       True               True  True       True        True          True
# 2       True               True  True       True        True          True
#
#    drive-wheels  engine-location  wheel-base  length  ...  engine-size  \
# 3          True             True        True    True  ...         True
# 3          True             True        True    True  ...         True
# 1          True             True        True    True  ...         True
# 2          True             True        True    True  ...         True
# 2          True             True        True    True  ...         True
#
#    fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# ...

# %%
for column in headers_data:
  print(column)
  print(missing_data[column].value_counts())
  print("")
# Out:
# symboling
# False    164
# True      41
# Name: symboling, dtype: int64
#
# normalized-losses
# False    205
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    203
# True       2
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    205
# Name: num-of-doors, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# ...

# %%
avg_bore = df["bore"].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3297512437810943

# %%
df["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
avg_bore = df["stroke"].astype('float').mean(axis=0)
print("Average of stroke:", avg_bore)
# Out:
# Average of stroke: 3.255422885572139

# %%
df["stroke"].replace(np.nan,avg_bore,inplace=True)

# %%
avg_horsepower = df["horsepower"].astype('float').mean(axis=0)
print("Average of horsepower:", avg_horsepower)
# Out:
# Average of horsepower: 104.25615763546799

# %%
df.to_csv("dataset2.csv")

# %%
df.dropna(subset=["price"],axis=0,inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.scatter(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
categories=['a','b','c','d']
values=[3,8,5,7]
plt.bar(categories,values)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.pie(x,y,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b35f1e3dc30>,
# ...
#  [Text(2.948275196030476, 0.9579526963642094, ''),
#   Text(1.5759865804870072, 4.850388262616186, ''),
#   Text(-6.752501409488903, 2.194020217511765, ''),
#   Text(2.8120557022065094, -8.65461395601721, '')],
#  [Text(2.4727469386062055, 0.8034441969506272, '10.0%'),
#   Text(1.4214780922039674, 4.374860001575383, '20.0%'),
#   Text(-6.276973141215037, 2.03951175148981, '30.0%'),
#   Text(2.6575471471402174, -8.179085716675605, '40.0%')])

# %%
labels=['categoryA','categoryB','categoryS']
size=[40,68,88]
plt.pie(size,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b35f1ea9240>,
# ...
#  [Text(0.881554969597829, 0.6579216029112976, 'categoryA'),
#   Text(-0.7901843509066363, 0.7652507377208192, 'categoryB'),
#   Text(0.17556000487995893, -1.0858999422997264, 'categoryS')],
#  [Text(0.48084816523517937, 0.35886632886070774, '20.4%'),
#   Text(-0.4310096459490743, 0.41740949330226496, '34.7%'),
#   Text(0.09576000266179578, -0.5923090594362143, '44.9%')])

# %%
df3=pd.read_csv('/content/dataset_3.data')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   88.60        204 non-null    float64
#  10  168.80       204 non-null    float64
#  11  64.10        204 non-null    float64
#  12  48.80        204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...

# %%
df["horsepower"]=df["horsepower"].astype(float)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names,include_lowest = True)
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0        111.0               Low
# 1        111.0               Low
# 2        154.0            Medium
# 3        102.0               Low
# 4        115.0               Low
# 5        110.0               Low
# 6        110.0               Low
# 7        110.0               Low
# 8        140.0            Medium
# 9        101.0               Low
# 10       101.0               Low
# 11       121.0            Medium
# 12       121.0            Medium
# 13       121.0            Medium
# 14       182.0            Medium
# 15       182.0            Medium
# 16       182.0            Medium
# 17        48.0               Low
# 18        70.0               Low
# 19        70.0               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
df4=pd.read_csv('/content/Dataset_4(Salary).csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          30 non-null     object
#  1   Salary           30 non-null     float64
#  2   YearsExperience  30 non-null     float64
#  3   Purchased        30 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 1.1+ KB

# %%
country_dummy = pd.get_dummies(df4['country'])

# %%
df4 = pd.concat([df4, country_dummy],axis = 1)

# %%
df4.drop('country',axis = 1, inplace = True)
df4 = df4[['Australia', 'Canada','Dubai', 'USA','YearsExperience','Salary','Purchased']]

# %%
df4
# Out:
#     Australia  Canada  Dubai  USA  YearsExperience    Salary Purchased
# 0           0       0      1    0              1.1   39343.0        No
# 1           0       1      0    0              1.3   46205.0       Yes
# 2           0       1      0    0              1.5   37731.0        No
# 3           0       1      0    0              2.0   43525.0        No
# 4           0       0      0    1              2.2   39891.0        No
# 5           0       0      1    0              2.9   56642.0        No
# 6           0       1      0    0              3.0   60150.0       Yes
# 7           1       0      0    0              3.2   54445.0        No
# 8           0       0      1    0              3.2   64445.0       Yes
# 9           0       0      1    0              3.7   57189.0        No
# 10          0       0      1    0              3.9   63218.0       Yes
# 11          0       0      0    1              4.0   55794.0        No
# ...

# %%
# Lets first perform label encoding on price column because it has only two unique values 'Yes' and 'No'

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df4['Purchased'] = le.fit_transform(df4['Purchased'])

# %%
# Lets perform one-hot encoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder',OneHotEncoder(), [0])], remainder='passthrough')
df = pd.DataFrame(ct.fit_transform(df4))

# %%
df4.columns = ['Australia','Canada','Dubai','USA','Salary', 'YearsExperience', 'Purchased']
df4.head(10)
# Out:
#    Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0          0       0      1    0     1.1          39343.0          0
# 1          0       1      0    0     1.3          46205.0          1
# 2          0       1      0    0     1.5          37731.0          0
# 3          0       1      0    0     2.0          43525.0          0
# 4          0       0      0    1     2.2          39891.0          0
# 5          0       0      1    0     2.9          56642.0          0
# 6          0       1      0    0     3.0          60150.0          1
# 7          1       0      0    0     3.2          54445.0          0
# 8          0       0      1    0     3.2          64445.0          1
# 9          0       0      1    0     3.7          57189.0          0

# %%
#You can find the sorted list of column names of encoding variable by this method.
#print(sorted(list(df4['country'].unique())
#To find the name of all the columns of dataset.
df4.columns
# Out:
# Index(['Australia', 'Canada', 'Dubai', 'USA', 'Salary', 'YearsExperience',
#        'Purchased'],
#       dtype='object')

# %%
df4.head()
# Out:
#    Australia  Canada  Dubai  USA  Salary  YearsExperience  Purchased
# 0          0       0      1    0     1.1          39343.0          0
# 1          0       1      0    0     1.3          46205.0          1
# 2          0       1      0    0     1.5          37731.0          0
# 3          0       1      0    0     2.0          43525.0          0
# 4          0       0      0    1     2.2          39891.0          0

# %%
# In X we store predictor variables.
# Here X will be dataframe because it has more than one features(columns).
X = df4.iloc[:,:-1]
#In y we store target variables.
#Here y will be pandas series as it has only one feature(column).
y = df4.iloc[:,-1]

#Here we are using X,y as dataframe because it has nice represenatation so you can understand it without confusion.
#But you can also use X,y as numpy array by this method.
        #X = df4.iloc[:,:-1].values
        #y = df4.iloc[:,-1].values

# %%
#Divide Data as Training Set and Testing Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 90)

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 29          0       1      0    0    10.5         121872.0
# 6           0       1      0    0     3.0          60150.0
# 20          0       1      0    0     6.8          91738.0
# 23          1       0      0    0     8.2         113812.0
# 25          1       0      0    0     9.0         105582.0
# 14          1       0      0    0     4.5          61111.0
# 8           0       0      1    0     3.2          64445.0
# 22          1       0      0    0     7.9         101302.0
# 15          0       0      0    1     4.9          67938.0
# 21          1       0      0    0     7.1          98273.0
# 9           0       0      1    0     3.7          57189.0
# 13          0       1      0    0     4.1          57081.0
# 16          0       0      0    1     5.1          66029.0
# 19          0       1      0    0     6.0          93940.0
# 11          0       0      0    1     4.0          55794.0
# ...

# %%
X_test
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 17          0       1      0    0     5.3          83088.0
# 24          0       0      1    0     8.7         109431.0
# 26          0       0      1    0     9.5         116969.0
# 2           0       1      0    0     1.5          37731.0
# 1           0       1      0    0     1.3          46205.0
# 12          0       0      1    0     4.0          56957.0

# %%
y_train
# Out:
# 29    1
# 6     1
# 20    0
# 23    1
# 25    1
# 14    0
# 8     1
# 22    0
# 15    0
# 21    0
# 9     0
# 13    0
# 16    0
# 19    0
# 11    0
# 0     0
# 10    1
# 28    0
# 5     0
# 4     0
# 7     0
# 3     0
# 18    1
# 27    1
# Name: Purchased, dtype: int64

# %%
y_test
# Out:
# 17    0
# 24    0
# 26    0
# 2     0
# 1     1
# 12    1
# Name: Purchased, dtype: int64
