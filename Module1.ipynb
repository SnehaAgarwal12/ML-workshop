# %%
import pandas as pd

# %%
dataset =pd.read_csv('/content/input.csv')

# %%
dataset
# Out:
#     boot_size  harness_size
# 0          39            58
# 1          38            58
# 2          37            52
# 3          39            58
# 4          38            57
# 5          35            52
# 6          37            55
# 7          36            53
# 8          35            49
# 9          40            54
# 10         40            59
# 11         36            56
# 12         38            53
# 13         39            58
# 14         42            57
# 15         42            58
# 16         36            56
# 17         36            51
# 18         35            50
# 19         41            59
# 20         42            59
# 21         38            59
# 22         37            55
# 23         35            50
# 24         40            55
# 25         36            52
# 26         35            53
# 27         39            54
# 28         41            61
# 29         37            56
# 30         35            55
# 31         41            60
# ...

# %%
dataset.head()
# Out:
#    boot_size  harness_size
# 0         39            58
# 1         38            58
# 2         37            52
# 3         39            58
# 4         38            57

# %%
dataset.tail()
# Out:
#     boot_size  harness_size
# 45         41            57
# 46         39            58
# 47         39            57
# 48         35            51
# 49         39            59

# %%
import statsmodels.formula.api as smf

# %%
formula="boot_size ~ harness_size"
model = smf.ols(formula=formula,data=dataset)

# %%
if not hasattr(model,'params'):
  print("model is selected but it doesnt have parameters set .we need to train the model!")
# Out:
# model is selected but it doesnt have parameters set .we need to train the model!

# %%
fitted_model = model.fit()
print("the following parameters have been found:\n"+
      f"Line Slope: {fitted_model.params[1]}\n"+
      f"Line Intercept:{fitted_model.params[0]}")
# Out:
# the following parameters have been found:
# Line Slope: 0.585925416738271
# Line Intercept:5.71910981268259

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset["harness_size"],dataset["boot_size"])
plt.plot(dataset["harness_size"],fitted_model.params[1]*dataset["harness_size"])
plt.xlabel("harness_size")
plt.ylabel("boot_size")
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
harness_size={'harness_size':[52.5]}
approximate_bootsize=fitted_model.predict(harness_size)
print(approximate_bootsize)
# Out:
# 0    36.480194
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(dataset['harness_size'],dataset['boot_size'])

# %%
plt.scatter(dataset['harness_size'],dataset['boot_size'])
plt.plot(dataset["harness_size"],fitted_model.params[1]*dataset["harness_size"]+fitted_model.params[0],'b',label="fitted line")
plt.xlabel("harness_size")
plt.ylabel("boot_size")
plt.legend()

# %%
dataset.mean()
# Out:
# boot_size       38.32
# harness_size    55.64
# dtype: float64

# %%
dataset.median()
# Out:
# boot_size       38.5
# harness_size    56.0
# dtype: float64

# %%
dataset.mode()
# Out:
#    boot_size  harness_size
# 0       39.0            57
# 1        NaN            58
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['boot_size'].plot(kind='hist', bins=20, title='boot_size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['harness_size'].plot(kind='hist', bins=20, title='harness_size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='boot_size', y='harness_size', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %%
import numpy as np
from sklearn import metrics

# %%
x=dataset["harness_size"]

# %%
y=dataset["boot_size"]

# %%
rmse=np.sqrt(metrics.mean_squared_error(x,y))
print('RMSE:',rmse)
# Out:
# RMSE: 17.435595774162696

# %%
approximate_bootsize=fitted_model.predict(dataset['harness_size'])

# %%
rmse=np.sqrt(metrics.mean_squared_error(y,approximate_bootsize))
print('RMSE:',rmse)
# Out:
# RMSE: 1.5560397381202649

# %%
print("average cost:",y.mean)
# Out:
# average cost: <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     39
# 1     38
# 2     37
# 3     39
# 4     38
# 5     35
# 6     37
# 7     36
# 8     35
# 9     40
# 10    40
# 11    36
# 12    38
# 13    39
# 14    42
# 15    42
# 16    36
# 17    36
# 18    35
# 19    41
# 20    42
# 21    38
# 22    37
# 23    35
# 24    40
# 25    36
# 26    35
# 27    39
# 28    41
# 29    37
# 30    35
# 31    41
# 32    39
# 33    41
# 34    42
# 35    42
# 36    36
# 37    37
# 38    37
# 39    39
# 40    42
# 41    35
# 42    36
# 43    41
# 44    41
# 45    41
# 46    39
# 47    39
# 48    35
# 49    39
# Name: boot_size, dtype: int64>

# %%
print("R-squared",metrics.r2_score(y,approximate_bootsize))
# Out:
# R-squared 0.5689868152575153

# %%
dataset2=pd.read_csv('/content/heart_cleveland_upload.csv')

# %%
dataset2.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
dataset.tail()
# Out:
#     boot_size  harness_size
# 45         41            57
# 46         39            58
# 47         39            57
# 48         35            51
# 49         39            59

# %%
from sklearn.model_selection import train_test_split
